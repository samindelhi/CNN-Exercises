# %% [markdown]
# <a href="https://colab.research.google.com/github/samindelhi/CNN-Exercises/blob/main/Yolo_Pretrained_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # YOLO pretrained Classification model v11.
# >**Y**ou **O**nly **L**earn **O**nce with Ultralytics. v 11.

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolo11m-cls.pt") # load a pretrained model

# %%
# predict with the model.
results  = model("https://ultralytics.com/images/bus.jpg")
# Out:
# ...
# image 1/1 /content/bus.jpg: 224x224 police_van 0.62, minibus 0.31, trolleybus 0.02, amphibian 0.01, minivan 0.01, 397.5ms
# Speed: 44.9ms preprocess, 397.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %%
from IPython.display import Image, display
display(Image(filename='bus.jpg'))

# %%
# predict with the model.
results  = model("https://media.istockphoto.com/id/2219332249/photo/green-vine-snake-long-nosed-whip-snake-ahaetulla-nasuta-sinharaja-national-park-rain-forest.jpg?s=1024x1024&w=is&k=20&c=Qo3uB5loiFGJDHqkh61vHrGG2tWUu6B5fWfkERXK_bM=")
# Out:
# ...
# image 1/1 /content/green-vine-snake-long-nosed-whip-snake-ahaetulla-nasuta-sinharaja-national-park-rain-forest.jpg: 224x224 vine_snake 0.86, green_snake 0.13, green_mamba 0.01, night_snake 0.00, horned_viper 0.00, 128.0ms
# Speed: 10.2ms preprocess, 128.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %%
model1 = YOLO("yolo11x-cls.pt")

# %%
results = model1("https://media.istockphoto.com/id/1444869833/photo/dinosaur-group.jpg?s=1024x1024&w=is&k=20&c=2CJSQLwWYOdPMFPzWu_-Mla_MwwzJWOukYqFcwJxP8o=")
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    result.save(filename="dino_result.jpg")  # save to disk
# Out:
# Found https://media.istockphoto.com/id/1444869833/photo/dinosaur-group.jpg locally at dinosaur-group.jpg
# image 1/1 /content/dinosaur-group.jpg: 224x224 triceratops 1.00, African_chameleon 0.00, African_crocodile 0.00, armadillo 0.00, Indian_elephant 0.00, 320.1ms
# Speed: 9.1ms preprocess, 320.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# <PIL.Image.Image image mode=RGB size=1024x576>

# %%
results = model1("https://media.istockphoto.com/id/171339165/photo/dinosaurs.jpg?s=1024x1024&w=is&k=20&c=9squIKpc-zE-vyyIgcBOd-yJGGWDwh7DlH8F6Iv_lrA=")
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    result.save(filename="dinos_result.jpg")  # save to disk
# Out:
# ...
# image 1/1 /content/dinosaurs.jpg: 224x224 triceratops 0.70, African_hunting_dog 0.05, black_grouse 0.03, curly-coated_retriever 0.01, kelpie 0.01, 322.7ms
# Speed: 11.7ms preprocess, 322.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# <PIL.Image.Image image mode=RGB size=1024x683>
